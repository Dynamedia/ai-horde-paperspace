# %%
import utils,json


### Set or get the API key. Never want this hardcoding in the notebook

api_key = utils.get_api_key()

utils.set_models()
for item, v in utils.models.items():
    print (v['name'] +" - " + str(v['eta']) +" - " + str(v['queued']))
# Out:
# stable_diffusion_2.1 - 15 - 355860480.0
# stable_diffusion - 21 - 1033666560.0
# waifu_diffusion - 0 - 13107200.0
# Furry Epoch - 7 - 26214400.0
# Yiffy - 7 - 30105600.0
# Zack3D - 0 - 0.0
# trinart - 3 - 15482880.0
# Coloring Book - 0 - 0.0
# Arcane Diffusion - 0 - 0.0
# Squishmallow Diffusion - 0 - 0.0
# Spider-Verse Diffusion - 0 - 0.0
# Archer Diffusion - 0 - 0.0
# Elden Ring Diffusion - 0 - 0.0
# Robo-Diffusion - 0 - 0.0
# mo-di-diffusion - 0 - 0.0
# Classic Animation Diffusion - 7 - 20971520.0
# Xynthii-Diffusion - 0 - 0.0
# Comic-Diffusion - 0 - 0.0
# Tron Legacy Diffusion - 0 - 0.0
# Microworlds - 4 - 15482880.0
# Zeipher Female Model - 0 - 0.0
# Redshift Diffusion - 3 - 15482880.0
# Borderlands - 0 - 0.0
# Cyberpunk Anime Diffusion - 0 - 0.0
# Midjourney Diffusion - 43 - 259653632.0
# Papercut Diffusion - 4 - 7864320.0
# AIO Pixel Art - 0 - 0.0
# JWST Deep Space Diffusion - 5 - 13762560.0
# App Icon Diffusion - 0 - 0.0
# Mega Merge Diffusion - 0 - 0.0
# Voxel Art Diffusion - 0 - 0.0
# Van Gogh Diffusion - 0 - 0.0
# Anything Diffusion - 18 - 667025408.0
# BubblyDubbly - 0 - 0.0
# Dungeons and Diffusion - 0 - 0.0
# Clazy - 7 - 15482880.0
# Nitro Diffusion - 0 - 0.0
# Samdoesarts Ultmerge - 4 - 9699328.0
# Synthwave - 0 - 0.0
# vectorartz - 0 - 0.0
# Ranma Diffusion - 0 - 0.0
# Ghibli Diffusion - 0 - 0.0
# Hentai Diffusion - 11 - 300154880.0
# Guohua Diffusion - 0 - 0.0
# Inkpunk Diffusion - 0 - 0.0
# Fantasy Card Diffusion - 0 - 0.0
# Knollingcase - 6 - 12288000.0
# Midjourney PaintArt - 3 - 15482880.0
# RPG - 1 - 15482880.0
# Poison - 0 - 0.0
# Eimis Anime Diffusion - 4 - 23592960.0
# Wavyfusion - 0 - 0.0
# Papercutcraft - 0 - 0.0
# kurzgesagt - 0 - 0.0
# ChromaV5 - 2 - 15482880.0
# Dreamlike Diffusion - 0 - 0.0
# Analog Diffusion - 0 - 0.0
# Asim Simpsons - 3 - 15482880.0
# Funko Diffusion - 0 - 0.0
# Double Exposure Diffusion - 14 - 46448640.0
# Microscopic - 0 - 0.0
# Balloon Art - 14 - 41697280.0
# Future Diffusion - 2 - 15482880.0
# Seek.art MEGA - 0 - 0.0
# Valorant Diffusion - 0 - 0.0
# Hassanblend - 31 - 319815680.0
# ACertainThing - 0 - 0.0
# GTA5 Artwork Diffusion - 0 - 0.0
# Trinart Characters - 0 - 0.0
# Smoke Diffusion - 0 - 0.0
# Supermarionation - 0 - 0.0
# Dreamlike Photoreal - 38 - 462422016.0
# PortraitPlus - 9 - 79036416.0
# Vintedois Diffusion - 0 - 0.0
# Darkest Diffusion - 7 - 15482880.0
# Eternos - 0 - 0.0
# Min Illust Background - 0 - 0.0
# Dark Victorian Diffusion - 0 - 0.0
# DnD Item - 0 - 0.0
# ModernArt Diffusion - 0 - 0.0
# HASDX - 0 - 0.0
# Liberty - 195 - 1599406080.0
# ProtoGen - 15 - 94126080.0
# 3DKX - 0 - 0.0
# Moedel - 0 - 0.0
# DreamLikeSamKuvshinov - 0 - 0.0
# Sygil-Dev Diffusion - 6 - 12288000.0
# MoistMix - 0 - 0.0
# Healy's Anime Blend - 0 - 0.0
# Elldreth's Lucid Mix - 0 - 0.0
# Sci-Fi Diffusion - 0 - 0.0
# Ultraskin - 28 - 221003776.0
# Sonic Diffusion - 0 - 0.0
# PPP - 1 - 6291456.0
# Anygen - 0 - 0.0
# Protogen Infinity - 4 - 32505856.0
# DucHaiten - 0 - 0.0
# Dreamshaper - 451 - 11591090176.0
# Zelda BOTW - 0 - 0.0
# Marvel Diffusion - 0 - 0.0
# T-Shirt Diffusion - 0 - 0.0
# Lawlas's yiff mix - 66 - 924057600.0
# DGSpitzer Art Diffusion - 0 - 0.0
# Realistic Vision - 7 - 135659520.0
# Dan Mumford Style - 0 - 0.0
# PFG - 1 - 6291456.0
# Epic Diffusion - 0 - 0.0
# Deliberate - 215 - 10248355840.0
# Concept Sheet - 0 - 0.0
# CharHelper - 0 - 0.0
# Pokemon3D - 0 - 0.0
# pix2pix - 0 - 0.0
# Vivid Watercolors - 0 - 0.0
# Counterfeit - 89 - 1051934720.0
# Openniji - 0 - 0.0
# Pastel Mix - 0 - 0.0
# Pulp Vector Art - 12 - 21987328.0
# Rainbowpatch - 2 - 9699328.0
# Vector Art - 0 - 0.0
# T-Shirt Print Designs - 0 - 0.0
# GorynichMix - 0 - 0.0
# Laolei New Berry Protogen Mix - 0 - 0.0
# URPM - 25 - 632750080.0
# Cheese Daddys Landscape Mix - 0 - 0.0
# Rachel Walker Watercolors - 2 - 9699328.0
# Project Unreal Engine 5 - 30 - 876216320.0
# Unstable Ink Dream - 4 - 12288000.0
# PRMJ - 0 - 0.0
# Elldreths Retro Mix - 0 - 0.0
# VinteProtogenMix - 0 - 0.0
# Rodent Diffusion - 2 - 15482880.0
# Anything v3 - 6 - 57589760.0
# Woop-Woop Photo - 5 - 37453824.0
# Abyss OrangeMix - 1 - 39321600.0
# CyriousMix - 1 - 13107200.0
# Microcasing - 0 - 0.0
# ChilloutMix - 55 - 1343045632.0
# Microchars - 0 - 0.0
# Microcritters - 0 - 0.0
# AbyssOrangeMix-AfterDark - 42 - 566067200.0
# Grapefruit Hentai - 0 - 0.0
# Experience - 0 - 0.0
# Kenshi - 0 - 0.0
# DucHaiten Classic Anime - 5 - 15482880.0
# Rev Animated - 26 - 651427840.0
# A to Zovya RPG - 3 - 15482880.0
# Colorful - 16 - 94126080.0
# Movie Diffusion - 4 - 15482880.0
# GuoFeng - 3 - 51380224.0
# Anime Pencil Diffusion - 0 - 0.0
# BPModel - 0 - 0.0
# UMI Olympus - 0 - 0.0
# HRL - 0 - 0.0
# Uhmami - 14 - 86261760.0
# NeverEnding Dream - 0 - 0.0
# Protogen Anime - 5 - 15482880.0
# SynthwavePunk - 8 - 12288000.0
# Graphic-Art - 0 - 0.0
# Illuminati Diffusion - 2 - 15482880.0
# SD-Silicon - 0 - 0.0
# FKing SciFi - 0 - 0.0
# RealBiter - 0 - 0.0
# FaeTastic - 1 - 15482880.0
# OrbAI - 0 - 0.0
# Realism Engine - 2 - 15482880.0
# Jim Eidomode - 4 - 39444480.0
# Dungeons n Waifus - 20 - 119808000.0
# iCoMix - 1 - 7864320.0
# TrexMix - 0 - 0.0
# Pretty 2.5D - 2 - 29491200.0
# ExpMix Line - 30 - 239206400.0
# Disco Elysium - 0 - 0.0
# Something - 0 - 0.0
# RCNZ Dumb Monkey - 0 - 0.0
# PIXHELL - 0 - 0.0
# Korestyle - 12 - 36700160.0
# PVC - 2 - 9699328.0
# Char - 0 - 0.0
# Perfect World - 2 - 15482880.0
# RCNZ Gorilla With A Brick - 2 - 15482880.0

# %%
print(nsfw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [77], line 1
# ----> 1 print(nsfw)
#
# NameError: name 'nsfw' is not defined

# %%
# !pip install nvidia_ml_py3 python-dotenv

import os, utils

# %load_ext dotenv
# !touch /notebooks/.env
# %dotenv -o /notebooks/.env

api_key = os.environ.get('API_KEY', False)
worker_name = os.environ.get('WORKER_NAME', False)

if not api_key or not worker_name:
    raise Exception('Worker details not found, Please run cell 1')

if not utils.is_key_valid(api_key):
    raise Exception('API key is invalid. Please run cell 1')
# Out:
# Requirement already satisfied: nvidia_ml_py3 in /usr/local/lib/python3.10/dist-packages (7.352.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.0)
